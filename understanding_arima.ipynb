# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Time variable
t = np.arange(100)

# Generate cyclical data
data = 0.05*t  +np.sin(2 * np.pi * t / 10) + np.random.normal(0, 0.1, 100)
print(data)

# Fit an ARIMA model
model = sm.tsa.ARIMA(data, order=(2, 1, 1))
model_fit = model.fit()
# Plot
plt.figure(figsize=(10, 4))
plt.plot(data, label='Original Data')
plt.plot(model_fit.fittedvalues, label='Fitted Values', color='red')
forecast_index = np.arange(100, 112)
forecast = model_fit.get_forecast(steps=12)
plt.plot(forecast_index,forecast.summary_frame()['mean'],color='green')
plt.legend()
plt.show()

print("AR Coefficients:", model_fit.arparams)
print("Model Summary:", model_fit.summary())
forecast = model_fit.get_forecast(steps=12)


residuals =  model_fit.resid[1:]

plt.plot(residuals)
print(sum(residuals))
# Out:
# [ 1.72130652e-03  5.34577653e-01  1.22382924e+00  9.49074167e-01
#   7.76781575e-01  1.52058751e-01 -1.11441065e-01 -6.33305155e-01
#  -6.31721716e-01 -2.26809617e-01  4.43819755e-01  1.19201464e+00
#   1.49409219e+00  1.57108721e+00  1.14210304e+00  7.32680706e-01
#   2.62664564e-01 -7.30232099e-02 -6.15858020e-02  2.92133074e-01
#   9.38142511e-01  1.67998657e+00  2.18189235e+00  2.22935755e+00
#   1.75592761e+00  1.09005162e+00  7.06397552e-01  5.62896339e-01
#   5.39739167e-01  7.24322912e-01  1.41997529e+00  2.20592664e+00
#   2.51442764e+00  2.53468164e+00  2.17741684e+00  1.67785535e+00
#   1.10338552e+00  1.04869169e+00  9.85684446e-01  1.34486923e+00
#   2.01528354e+00  2.53331057e+00  3.11567275e+00  3.03802488e+00
#   2.68510791e+00  2.11051789e+00  1.76386192e+00  1.34508735e+00
#   1.42345793e+00  1.95884252e+00  2.37937667e+00  3.35004242e+00
#   3.52635220e+00  3.67491930e+00  3.44852505e+00  2.72172056e+00
#   2.08099958e+00  2.06662317e+00  1.91478367e+00  2.36973617e+00
#   3.02668766e+00  3.67013456e+00  4.11922615e+00  4.16089569e+00
#   3.84098034e+00  3.20955544e+00  2.68843651e+00  2.41139270e+00
#   2.49377069e+00  2.85739311e+00  3.68986597e+00  4.27265476e+00
#   4.52674858e+00  4.52493664e+00  4.14013564e+00  3.68033256e+00
#   3.35886870e+00  2.90851839e+00  2.97501650e+00  3.19766691e+00
#   4.02728604e+00  4.48131214e+00  4.97478560e+00  5.00477196e+00
#   4.62251931e+00  4.32727926e+00  3.89771454e+00  3.43676669e+00
#   3.55089178e+00  3.87789125e+00  4.49441472e+00  4.94526403e+00
#   5.58179598e+00  5.52596513e+00  5.16295755e+00  4.81413143e+00
#   4.13865294e+00  3.77735242e+00  3.89032625e+00  4.29257525e+00]
# /Users/parvizpirizade/Documents/stock_price_prediction/time_series_analysis/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/parvizpirizade/Documents/stock_price_prediction/time_series_analysis/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR Coefficients: [ 1.48948706 -0.85125061]
# Model Summary:                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                   2.591
# Date:                Sat, 18 May 2024   AIC                              2.818
# Time:                        17:17:34   BIC                             13.199
# Sample:                             0   HQIC                             7.018
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4895      0.062     23.910      0.000       1.367       1.612
# ar.L2         -0.8513      0.063    -13.597      0.000      -0.974      -0.729
# ma.L1         -0.7701      0.090     -8.596      0.000      -0.946      -0.595
# sigma2         0.0542      0.008      7.168      0.000       0.039       0.069
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.59   Jarque-Bera (JB):                 2.68
# Prob(Q):                              0.00   Prob(JB):                         0.26
# Heteroskedasticity (H):               0.88   Skew:                            -0.30
# Prob(H) (two-sided):                  0.71   Kurtosis:                         3.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 7.274412425688791
